# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import Score_assignment
import Score_cluster
import Score_physics
from Plotting import *

# %%
df = pd.read_csv("result_truth_10.csv")

# %%
df
# Out:
#     Unnamed: 0  event  particle  track  hit         x         y
# 0            0      0         0      0    0 -0.690865  0.465994
# 1            1      0         0      0    1 -0.706707  0.441599
# 2            2      0         3      0    2 -0.832826  0.029083
# 3            3      0         1      1    3  0.690865 -0.465994
# 4            4      0         1      1    4  0.706707 -0.441599
# 5            5      0         1      1    5  0.721688 -0.416667
# 6            6      0         0     -1    6 -1.082532  0.625000
# 7            7      0         3     -1    7 -1.246955 -0.087196
# 8            8      0         3     -1    8 -1.243152 -0.130661
# 9            9      0         1     -1    9  1.103684 -0.586839
# 10          10      0         1     -1   10  1.123493 -0.547964
# 11          11      0         0     -1   11 -1.497990  0.730619
# 12          12      0         3      2   12 -1.650447 -0.231955
# 13          13      0         3      2   13 -1.641346 -0.289414
# ...

# %%
ievent = 0
iparticle=1001
itrack = 1002

df_event=df.loc[df['event']==ievent]
df_particle=df_event[df['particle']==iparticle]
df_track=df_event[df['track']==itrack]
# Out:
# /Library/Python/2.7/site-packages/pandas/core/frame.py:1686: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
Score_assignment.evaluate(df_event['particle'].values.astype('int64'),df_event['track'].values.astype('int64'))
# Out:
# [2 3 3]
# 3 22 0.363636363636
# 0.36363636363636365

# %%
df_event.sort('particle')
# Out:
#     Unnamed: 0  event  particle  track  hit         x         y
# 0            0      0         0      0    0 -0.690865  0.465994
# 17          17      0         0     -1   17 -1.931633  0.780430
# 11          11      0         0     -1   11 -1.497990  0.730619
# 20          20      0         0     -1   20 -2.403154  0.689093
# 6            6      0         0     -1    6 -1.082532  0.625000
# 21          21      0         0     -1   21 -2.852931  0.606409
# 1            1      0         0      0    1 -0.706707  0.441599
# 4            4      0         1      1    4  0.706707 -0.441599
# 9            9      0         1     -1    9  1.103684 -0.586839
# 3            3      0         1      1    3  0.690865 -0.465994
# 15          15      0         1     -1   15  1.545306 -0.624344
# 16          16      0         1     -1   16  1.566154 -0.570034
# 18          18      0         1     -1   18  2.002629 -0.574244
# 19          19      0         1     -1   19  2.021449 -0.504004
# ...

# %%
plt.scatter(df_event['x'].values,df_event['y'].values)
plt.show()

# %%
plt.scatter(df_particle['x'].values,df_particle['y'].values)
plt.show()

# %%
plt.scatter(df_track['x'].values,df_track['y'].values)
plt.show()

# %%
y_test=df_event['particle'].values.astype(int)
y_pred=df_event['track'].values.astype(int)

# %%
Score_cluster.evaluate(y_test, y_pred,-1)
# Out:
# /Library/Python/2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(14, -1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# (0.0, 0.0)

# %%
from analyze import *

# %%
g_eff, g_fake, g_npar = analyze()
# Out:
# /Library/Python/2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(101, -1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /Library/Python/2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(77, -1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /Library/Python/2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(28, -1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /Library/Python/2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(27, -1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# ...

# %%
x,y=plotinbins(g_npar ,g_eff, binsize=1)
plt.plot(x,y)
plt.show()

# %%
x=g_npar
y=g_eff

# %%
x=g_npar
y=g_eff

# %%
x=np.array(['a','b','c','d','e'])

# %%
x
# Out:
# array(['a', 'b', 'c', 'd', 'e'],
#       dtype='|S1')

# %%
x[[0,3,4,2]]
# Out:
# array(['a', 'd', 'e', 'c'],
#       dtype='|S1')
